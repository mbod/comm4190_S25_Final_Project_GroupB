# %% [markdown]
# # LoveSense Custom GPT Configuration
# **Instructions used to configure the custom LoveSense GPT chatbot for User Scenarios 1, 2, 3, and 4**
#
# **Link to try:** https://chatgpt.com/g/g-68190335f8548191b419935b02e45092-lovesense
#
# ![LoveSense Chatbot](attachment:a3d55380-e46a-42cd-a9de-9e9a37af85f5.png)
#
# ![Custom GPT LoveSense Configuration](attachment:79b74da9-da9c-4719-a2d7-1ef8301e04f7.png)
#
# ![Instructions given](attachment:257c5ea8-3696-456a-a570-3609f3adffd8.png)
