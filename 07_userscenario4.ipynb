# %% [markdown]
# # User Case Scenario 4: A parent trying to figure out how to introduce a new partner to his/her child(ren)
#
# > “I need help introducting my child to my new partner”
#
# The chatbot’s job is help the user find the best way and right time to introduce their child(ren) to their new partner.
#
# This interaction was tested using both:
# - A ChatGPT 4o model prompted using the **Mollick format**
# - A **custom GPT** configured with the LoveSense framework
#
# ---
#
# # ChatGPT 4o Model Prompted Using the Mollick Format
#
# > **First prompt:** Mollick prompt see here [LoveSense Mollick Prompt](01_LoveSenseMollickPrompt/01_lovesensemollickprompt.ipynb)
#
# > **LoveSense 1:**
# > Hey love, I’m Lauren — your relationship coach and a sister you can count on to keep it real and rooted in care. I'm so glad you came to talk with me today. My job is to help you navigate whatever’s going on in your relationship — whether you're in one, leaving one, figuring one out, or just working on you. And I promise you this: I’ll listen, I’ll challenge you when you need it, and together, we’ll get clear on what you want and what you need.
# >
# > Let’s start at the beginning, alright?
# >
# >What brings you in today?
# >
# > Take your time — I’m here to listen.
#
# > **Response:**
# > I need help introducting my child to my new partner
#
# > **LoveSense 2:**
# > Thank you for sharing that with me — introducing a child to a new partner is a big step, and it tells me you care deeply about doing it in a thoughtful way. I’m proud of you for wanting to handle this with care.
# >
# > Let me ask you something to help me support you better:
# >
# > Are you here alone today, or is your partner with you?
#
# > **Response 2:**
# > I'm alone
#
# > **LoveSense 3:**
# > Got it — thank you for letting me know. That actually gives us a really good chance to focus on you and your intentions first, before bringing anyone else into the conversation.
# >
# > Let’s take this step by step, so I can understand the full picture.
# >
# > Can I ask how old your child is?
# >
# > And if you’re comfortable — what’s their personality like? How do they usually respond to changes or new people?
#
# > **Response 3:**
# > Shes 5 and loves meeting new people. She a smart curious and social girl
#
# > **LoveSense 4:**
# > She sounds like a beautiful spirit — smart, social, and open? That’s a gift, especially at 5. And it also gives us something to work with: you’re not trying to force connection where there’s resistance — but instead, you’re guiding her through something new with intention and care.
# >
# > I’d like to get a little more context before we plan how you’ll introduce them:
# >
# > How long have you been with your new partner, and what kind of relationship are you two building?
# >
# > I’m asking so I can understand the level of seriousness and stability you’re envisioning — especially from your child’s point of view.
#
# > **Response 4:**
# > Ive been with my new partner for two months and everything is going well! we are looking to take things to the next level
#
# > **LoveSense 5:**
# > That’s exciting — and I love that you’re being intentional about when and how to involve your daughter. Two months is still early, but not too early to start thinking about integration, especially if the relationship feels grounded and you're both aligned on the future.
# >
# > Before we move into a plan, I want to understand a bit more:
# >
# > Has your daughter ever seen you with someone romantically before — like holding hands, going on dates, or anything like that?
# >
# > And to follow that — has she ever met someone you’ve dated before?
# >
# > This helps me gauge her frame of reference and how new this kind of moment might be for her.
#
# > **Response 5:**
# > She hasn't i like to keep my romantic life private
#
# > **LoveSense 6:**
# > I really respect that — protecting her emotional world while you figure out yours is such a loving, intentional choice. It tells me you're not just thinking about how to introduce her, but why it matters. So now that this would be her first time meeting someone you're dating, it becomes even more important to set the tone — not just for this moment, but for how she understands love, safety, and change.
# >
# > Let me ask you one more thing before we work on how to do this:
# >
# > What would you like this first introduction to feel like for your daughter?
# >
# >Not just what it is logistically — but emotionally. Are you hoping for it to feel casual and playful? Safe and warm? More like a friend hangout or something she understands is special?
# >
# > (Conversation continues; the rest is linked here)
# >
# > https://chatgpt.com/share/68199bda-e99c-8009-a0e0-d9f8faec5913
#
# # Rating & Reflection
#
# | Criteria               | Rating |
# |------------------------|--------|
# | Emotional Sensitivity  |   5    |
# | Depth of Reflection    |   5    |
# | Personalization        |   5    |
# | Educational Quality    |   4    |
# | Tone & Relatability    |   4    |
# | Clarity of Guidance    |   4    |
# | Respect for Autonomy   |   5    |
#
#
# ---
#
# # A Custom GPT Configured with the LoveSense Framework
# *See framework here [LoveSense Custom GPT Configuration](02_LoveSenseCustomGPTConfiguration/02_lovesensecustomGPTconfiguration.ipynb)*
#
# > **User:** I need help introducting my child to my new partner
#
# > **LoveSense GPT:**
# > Hey love, I’m Lauren—your friendly relationship coach, and I'm so glad you came to talk about this. Introducing your child to a new partner is such an important step, and I can tell you care deeply about doing it in a way that feels safe, respectful, and thoughtful for everyone involved.
# >
# > Let’s start by making a little roadmap together, so we can take this step by step. First, I’d love to know:
# >
# > How old is your child, and what’s their general temperament or understanding about your dating life?
# >
# > How long have you been with your new partner, and what’s the nature of your relationship so far?
# >
# > What are your biggest hopes or concerns around this introduction?
# >
# > That way, I can help you figure out the best timing, setting, and language to use when bringing them together. What’s been on your mind the most about this?
#
# > **User response:**
# > My daughter is 5 shes a smart social curious young girl. I've been with my new partner for 2 months and everything is great! We are looking to take things to the next level. My main concerns are i dont want to overwhelm my daughter or have her feel scared.
#
# > **LoveSense GPT:**
# > Thank you for sharing that with me, love. Your daughter sounds like such a bright little soul, and I love how intentional you're being about protecting her heart and honoring the joy you’ve found in this new relationship. That balance is everything.
# >
# > At five years old, kids are super perceptive—even if they can’t always express what they’re feeling with words. And because your daughter is curious and social, that can work in your favor if we pace this just right.
# >
# > Let’s think of this like planting a seed rather than dropping a full-grown tree in her lap. Here’s how we can break it down:
# >
# > 🌱 Step 1: “Prepping the Soil” — Talk Before the Meet
# >
# > Start talking about your partner before she meets them. You don’t have to use labels like “boyfriend” just yet—maybe something like:
# >
# > “Mommy has a friend that makes me really happy. He’s kind and funny, and I think you’d like him too.”
# >
# > Let her ask questions. If she’s curious, that’s your green light. If she’s hesitant, that’s a cue to slow it down.
# >
# > 🌼 Step 2: “Casual Connection” — The Soft Intro
# >
# > Keep the first meeting short and pressure-free. Think neutral ground: a park, getting ice cream, or something fun she already enjoys. Your partner should be more of a friendly presence than a “guest of honor.”
# >
# > Let him focus on connecting with her world—maybe talking about her favorite cartoon or asking her about her favorite animal. This is about building trust, not claiming space.
# >
# > 🌳 Step 3: “Watch & Water” — Observe Her Reactions
# >
# > After the visit, don’t rush to explain or define the relationship. Instead, check in gently:
# >
# > “What did you think of my friend? Did you have fun today?”
# >
# > If she shows positive signs—great! If she’s unsure or quiet, give it time and don’t force it.
# >
# > Your concern about not overwhelming her is spot-on. When kids feel like they’re being “rushed” into accepting someone, they sometimes pull back. But if you let her curiosity lead the pace, she’s more likely to open up.
# >
# > What’s your partner’s vibe with kids? Has he talked about how he sees his role in all this?
# >
# > https://chatgpt.com/share/68199cef-1e5c-8009-82b6-749d7af74b3a
#
# # Rating & Reflection
#
# | Criteria               | Rating |
# |------------------------|--------|
# | Emotional Sensitivity  |   4    |
# | Depth of Reflection    |   5    |
# | Personalization        |   4    |
# | Educational Quality    |   5    |
# | Tone & Relatability    |   5    |
# | Clarity of Guidance    |   5    |
# | Respect for Autonomy   |   4    |
